# %% [markdown]
# Загружаем библиотеки, рестартуем Kernel

# %%
# !pip install psycopg2-binary
# !pip install boto3
# !pip install mlflow==2.7.0
# !pip install -U scikit-learn

# %% [markdown]
# # Load data from postgre

# %% [markdown]
# #### Задача: определение кредитного рейтинга клиента на основе данных о его кредитной истории.

# %% [markdown]
# Загружаем обучающие данные из Postgre

# %%
import pandas as pd
import psycopg2 as pg

dataset_name = "train_cs"

engine = pg.connect("host=cassandra-postgresql.feast-db port=5432 dbname=FEAST_OFFLINE_STORE user=postgres password=postgres")
df = pd.read_sql(f'select * from {dataset_name}', con=engine)

# %% [markdown]
# Посмотрим на данные

# %%
df.head()
# Out:
#    Month         Age  Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0      2   23.000000           4       19114.12            4205.502940
# 1      3  116.302136           4       19114.12            4205.502940
# 2      4   23.000000           4       19114.12            4205.502940
# 3      5   23.000000           4       19114.12            1824.843333
# 4      7   23.000000           4       19114.12            1824.843333
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                  3                4              3          4.0
# 1                  3                4              3          4.0
# 2                  3                4              3          4.0
# 3                  3                4              3          4.0
# 4                  3                4              3          4.0
#
#    Delay_from_due_date  ...  Credit_Mix  Outstanding_Debt  \
# 0                    1  ...           1            809.98
# 1                    3  ...           1            809.98
# 2                    5  ...           1            809.98
# 3                    6  ...           1            809.98
# 4                    3  ...           1            809.98
#
#    Credit_Utilization_Ratio  Credit_History_Age  Payment_of_Min_Amount  \
# 0                 31.944960           17.961599                      2
# 1                 28.609352           22.000000                      2
# 2                 31.377862           22.000000                      2
# 3                 24.797347           22.000000                      2
# 4                 22.537593           22.000000                      2
#
#    Total_EMI_per_month  Amount_invested_monthly  Payment_Behaviour  \
# 0            49.574949               118.280222                6.0
# 1            49.574949                81.699521                3.0
# 2            49.574949               199.458074                1.0
# 3            49.574949                41.420153                2.0
# 4            49.574949               178.344067                1.0
#
#    Monthly_Balance  Credit_Score
# 0       284.629162             2
# 1       331.209863             2
# 2       223.451310             2
# 3       341.489231             2
# 4       244.565317             2
#
# [5 rows x 23 columns]

# %% [markdown]
# # Prepare data

# %% [markdown]
# Отделим фичи от таргетов сохранив их в разные переменные

# %%
train_data = df.drop("Credit_Score",axis=1)
label_data = df["Credit_Score"]

# %% [markdown]
# Разделим фичи и таргеты на датасеты для обучения и тестирования

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(train_data, label_data ,test_size=0.2, random_state=42)

# %% [markdown]
# # Train Model

# %% [markdown]
# Обучим модель на тренировачных данных и получим ее accuracy (точность) на тестовом датасете.

# %%
from sklearn.ensemble import GradientBoostingClassifier

clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=3, random_state=0).fit(X_train, y_train)
score = clf.score(X_test, y_test)
score
# Out:
# 0.7327347057964666

# %% [markdown]
# # Log Model

# %% [markdown]
# Залогируем модель в MLFlow, так же залогируем метрику точности работы модели на тестовом датасете.

# %%
import mlflow

mlflow.set_experiment("Credit Score Classification")

with mlflow.start_run() as run:
    
    mlflow.log_metrics({"accuracy": score})
    
    mlflow.sklearn.log_model(
        sk_model=clf,
        artifact_path="model",
    )

# %% [markdown]
# После логирования модели переходим в MLFlow, регистрируем модель, переводим ее в стейдж Production.

# %% [markdown]
# Затем запускаем граф Airflow

# %% [markdown]
# # Test results

# %% [markdown]
# После того как граф отработал, можем проверить результат работы выгрузив датасет с полученным кредитным рейтингом для каждого клиента.

# %% [markdown]
# Предсказанный кредитный рейтинг сохраняется в колонке results

# %%
import pandas as pd
import psycopg2 as pg

dataset_name = "results_cs"

engine = pg.connect("host=cassandra-postgresql.feast-db port=5432 dbname=FEAST_OFFLINE_STORE user=postgres password=postgres")
df_res = pd.read_sql(f'select * from {dataset_name}', con=engine)
df_res.head()
# Out:
#    Month   Age  Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0     12  16.0           1       72471.32            6097.276667
# 1      9  20.0          13       43430.88            3418.240000
# 2     10  20.0          13       43430.88            3418.240000
# 3     11  20.0          13       43430.88            3418.240000
# 4     12  20.0          13       43430.88            3418.240000
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                  8               10             30     3.364257
# 1                  6                4             12     1.000000
# 2                  6                4             12     1.000000
# 3                  6                4             12     1.000000
# 4                  6                4             12     1.000000
#
#    Delay_from_due_date  ...  Credit_Mix  Outstanding_Debt  \
# 0                   23  ...           3           4439.31
# 1                   20  ...           2           1288.94
# 2                   20  ...           2           1288.94
# 3                   20  ...           2           1288.94
# 4                   17  ...           2           1288.94
#
#    Credit_Utilization_Ratio  Credit_History_Age  Payment_of_Min_Amount  \
# 0                 29.975945                 3.0                      1
# 1                 35.571842                18.0                      2
# 2                 25.260261                18.0                      2
# 3                 35.908725                18.0                      2
# 4                 39.172962                18.0                      2
#
#    Total_EMI_per_month  Amount_invested_monthly  Payment_Behaviour  \
# 0           394.144658               169.118693                2.0
# 1            20.440818                61.287485                2.0
# 2            20.440818               186.594681                1.0
# 3            20.440818                60.241992                4.0
# 4            20.440818                58.729698                4.0
#
#    Monthly_Balance  results
# 0       296.464316        1
# 1       510.095697        0
# 2       424.788501        0
# 3       501.141190        0
# 4       502.653484        0
#
# [5 rows x 23 columns]

# %% [markdown]
# # Test Logged Model

# %%
import pandas as pd
import psycopg2 as pg

dataset_name = "test_cs"

engine = pg.connect("host=cassandra-postgresql.feast-db port=5432 dbname=FEAST_OFFLINE_STORE user=postgres password=postgres")
df_test = pd.read_sql(f'select * from {dataset_name}', con=engine)

# %%
df.head()
# Out:
#    Month         Age  Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0      2   23.000000           4       19114.12            4205.502940
# 1      3  116.302136           4       19114.12            4205.502940
# 2      4   23.000000           4       19114.12            4205.502940
# 3      5   23.000000           4       19114.12            1824.843333
# 4      7   23.000000           4       19114.12            1824.843333
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                  3                4              3          4.0
# 1                  3                4              3          4.0
# 2                  3                4              3          4.0
# 3                  3                4              3          4.0
# 4                  3                4              3          4.0
#
#    Delay_from_due_date  ...  Credit_Mix  Outstanding_Debt  \
# 0                    1  ...           1            809.98
# 1                    3  ...           1            809.98
# 2                    5  ...           1            809.98
# 3                    6  ...           1            809.98
# 4                    3  ...           1            809.98
#
#    Credit_Utilization_Ratio  Credit_History_Age  Payment_of_Min_Amount  \
# 0                 31.944960           17.961599                      2
# 1                 28.609352           22.000000                      2
# 2                 31.377862           22.000000                      2
# 3                 24.797347           22.000000                      2
# 4                 22.537593           22.000000                      2
#
#    Total_EMI_per_month  Amount_invested_monthly  Payment_Behaviour  \
# 0            49.574949               118.280222                6.0
# 1            49.574949                81.699521                3.0
# 2            49.574949               199.458074                1.0
# 3            49.574949                41.420153                2.0
# 4            49.574949               178.344067                1.0
#
#    Monthly_Balance  Credit_Score
# 0       284.629162             2
# 1       331.209863             2
# 2       223.451310             2
# 3       341.489231             2
# 4       244.565317             2
#
# [5 rows x 23 columns]

# %%
import mlflow

model_name = "csgb"
stage = "Production"

model = mlflow.sklearn.load_model(f"models:/{model_name}/{stage}")
# Out:
# Downloading artifacts:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
model.predict(df_test)
# Out:
# array([1, 0, 0, ..., 1, 0, 1])
